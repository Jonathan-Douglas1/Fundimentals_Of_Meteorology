# %%
import sys
print(sys.executable)
import numpy as np
import pandas as pd
import xarray as xr
import matplotlib.pyplot as plt
# Out:
# /opt/anaconda3/envs/spyder-env/bin/python

# %%
print("Hello, World!")
# Out:
# Hello, World!
